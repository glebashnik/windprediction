# %% [markdown]
# # Ulike datasett  Versjon 1.0

# %% [markdown]
# her komme noe tekst

# %% [markdown]
# #### Importere biblioteker

# %%
import pandas as pd
import numpy as np

# Visualization
#import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# Making plots look better
import matplotlib as mpl
mpl.rcParams['patch.force_edgecolor'] = True

# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# #### Innlasting av ulike datasett

# %%
# TEK (1. Spetember til 18. Desember)
df_tek = pd.read_csv('vindkraft 181217 TEK met.csv',sep =';', low_memory = False)
    #df_tek.info()

# TEK (delayed 2 hours)
#df_tek_delayed = pd.read_csv('vindkraft 181217 TEK met delayed_2.csv',sep =';', low_memory = False)
    #df_tek_delayed.info()

# AROME Værdata (1. Spetember til 18. Desember)
df_arome = pd.read_csv('vindkraft 181217 arome.csv',sep =';', low_memory = False)
    #df_arome.info()
    
df_tek.columns
# Out:
# Index(['Unnamed: 0', 'BESS-Bessakerfj.-G1-T-0  A0 -0000',
#        'BESS-Bessakerfj.-G2-T-0  A0 -0000',
#        'BESS-Bessakerfj.-G3-T-0  A0 -0000',
#        'BESS-Bessakerfj.-G4-T-0  A0 -0000',
#        'BESS-Bessakerfj.-G5-T-0  A0 -0000',
#        'BESS-Bessakerfj.-G6-T-0  A0 -0000',
#        'BESS-Bessakerfj.-G7-T-0  A0 -0000',
#        'BESS-Bessakerfj.-G8-T-0  A0 -0000',
#        'BESS-Bessakerfj.-G9-T-0  A0 -0000',
#        ...
#        'RRS.S2502.Gunit.M15 G1.AVL', 'RRS.S2502.Gunit.M16 G1.AVL',
#        'RRS.S2502.Gunit.M17 G1.AVL', 'BESS-Bessakerfj.-GS-T4015A3 -0104',
#        'VALS-Valsneset..-GS1-5-T4015A3 -0104',
#        'SKOM-Skomakerfj.-GS-T4015A3 -0104', 'YVIK-YtreVikna1-Sum-produksjon',
#        'SKOM-SfjHydLt30mMid-T0018A3 -0114',
#        'SKOM-SfjHydVindrMid-T0014A3 -0113',
#        'SKOM-SfjHydVindhMid-T0016A3 -0120'],
#       dtype='object', length=299)

# %% [markdown]
# #### Beregning av variablen 'antall_vinturbiner'

# %%
df_antall_fungerende_vinturbiner = df_tek[['RRS.S2502.Gunit.M1 G1.AVL',
                     'RRS.S2502.Gunit.M2 G1.AVL',
                     'RRS.S2502.Gunit.M3 G1.AVL',
                     'RRS.S2502.Gunit.M4 G1.AVL',
                     'RRS.S2502.Gunit.M5 G1.AVL',
                     'RRS.S2502.Gunit.M6 G1.AVL',
                     'RRS.S2502.Gunit.M7 G1.AVL',
                     'RRS.S2502.Gunit.M8 G1.AVL',
                     'RRS.S2502.Gunit.M9 G1.AVL',
                     'RRS.S2502.Gunit.M10 G1.AVL',
                     'RRS.S2502.Gunit.M11 G1.AVL',
                     'RRS.S2502.Gunit.M12 G1.AVL',
                     'RRS.S2502.Gunit.M13 G1.AVL',
                     'RRS.S2502.Gunit.M14 G1.AVL',
                     'RRS.S2502.Gunit.M15 G1.AVL',
                     'RRS.S2502.Gunit.M16 G1.AVL',
                      'RRS.S2502.Gunit.M17 G1.AVL'
                     ]]

# %%
# Summer alle kollonnene - dvs. teller antall fungerende vindturbiner (1 = fungerer, 0 = ute av drift)
df_antall_fungerende_vinturbiner['antall_fungerende'] = df_tek['RRS.S2502.Gunit.M1 G1.AVL'] + df_tek['RRS.S2502.Gunit.M2 G1.AVL'] + df_tek['RRS.S2502.Gunit.M3 G1.AVL'] + df_tek['RRS.S2502.Gunit.M4 G1.AVL'] + df_tek['RRS.S2502.Gunit.M5 G1.AVL'] + df_tek['RRS.S2502.Gunit.M6 G1.AVL'] +df_tek['RRS.S2502.Gunit.M7 G1.AVL'] + df_tek['RRS.S2502.Gunit.M8 G1.AVL'] + df_tek['RRS.S2502.Gunit.M9 G1.AVL'] + df_tek['RRS.S2502.Gunit.M10 G1.AVL'] + df_tek['RRS.S2502.Gunit.M11 G1.AVL'] + df_tek['RRS.S2502.Gunit.M12 G1.AVL'] + df_tek['RRS.S2502.Gunit.M13 G1.AVL'] + df_tek['RRS.S2502.Gunit.M14 G1.AVL'] + df_tek['RRS.S2502.Gunit.M15 G1.AVL'] + df_tek['RRS.S2502.Gunit.M16 G1.AVL'] + df_tek['RRS.S2502.Gunit.M17 G1.AVL']

# %% [markdown]
#  ## Datasett 'Data 0.0.csv'

# %%
data_0_0 = pd.concat([
                df_tek['STORM-YVik1-Vindhast-25km'],
                df_tek['STORM-YVik1-Vindretn-25km'], 
                df_tek['YVIK-YtreVikna1-Sum-produksjon'],                      
               ], 
               axis = 1)

# %%
data_0_0.to_csv('Data 0.0.csv', sep=';', index = False)

# %% [markdown]
# ## Datasett:                  'Data 0.1.csv'

# %%
data_0_1 = pd.concat([
                df_tek['STORM-YVik1-Vindhast-25km'],
                df_tek['STORM-YVik1-Vindretn-25km'],
                df_tek_delayed['YVIK-YtreVikna1-Sum-produksjon (2 hours before)'],
                df_tek['YVIK-YtreVikna1-Sum-produksjon'],                      
               ], 
               axis = 1)

# %%
data_0_1.to_csv('Data 0.1.csv', sep=';', index = False)

# %% [markdown]
# ## Datasett: 'Data 0.2.csv'

# %%
data_0_2 = pd.concat([
                df_tek['STORM-YVik1-Vindhast-25km'],
                df_tek['STORM-YVik1-Vindretn-25km'],
                df_antall_fungerende_vinturbiner['antall_fungerende'],
                df_tek_delayed['YVIK-YtreVikna1-Sum-produksjon (2 hours before)'],
                df_tek['YVIK-YtreVikna1-Sum-produksjon'],                      
               ], 
               axis = 1)

# %%
data_0_2.to_csv('Data 0.2.csv', sep=';', index = False)

# %% [markdown]
# # Inkludering av informasjonen fra Arome

# %% [markdown]
# ##### 'Data 1.0.csv'

# %%
data_1_0 = pd.concat([
                df_arome['/arome_airtemp_6491_1087'],
                df_arome['/arome_airpress_6491_1087'], 
                df_arome['/arome_winddir_6491_1087'],
                df_arome['/arome_windvel_6491_1087'],
                
                df_tek['YVIK-YtreVikna1-Sum-produksjon'], 
               ], 
               axis = 1)

# %%
data_1_0.to_csv('Data 1.0.csv', sep=';', index = False)

# %% [markdown]
# #### 'Data 1.1.csv'

# %%
data_1_1 = pd.concat([
                df_arome['/arome_airtemp_6491_1087'],
                df_arome['/arome_airpress_6491_1087'], 
                df_arome['/arome_winddir_6491_1087'],
                df_arome['/arome_windvel_6491_1087'],
                
                df_tek_delayed['YVIK-YtreVikna1-Sum-produksjon (2 hours before)'],
                
                df_tek['YVIK-YtreVikna1-Sum-produksjon'], 
               ], 
               axis = 1)

# %%
data_1_1.to_csv('Data 1.1.csv', sep=';', index = False)

# %% [markdown]
# #### 'Data 1.2.csv'

# %%
data_1_2 = pd.concat([
                df_arome['/arome_airtemp_6491_1087'],
                df_arome['/arome_airpress_6491_1087'], 
                df_arome['/arome_winddir_6491_1087'],
                df_arome['/arome_windvel_6491_1087'],
                
                df_antall_fungerende_vinturbiner['antall_fungerende'],
                
                df_tek_delayed['YVIK-YtreVikna1-Sum-produksjon (2 hours before)'],
                
                df_tek['YVIK-YtreVikna1-Sum-produksjon'], 
               ], 
               axis = 1)

# %%
data_1_2.to_csv('Data 1.2.csv', sep=';', index = False)

# %% [markdown]
# #### 'Data 2.0.csv'

# %%
data_2_0 = pd.concat([
                
                df_arome['/arome_airtemp_6495_1081'],
                df_arome['/arome_airpress_6495_1081'], 
                df_arome['/arome_winddir_6495_1081'],
                df_arome['/arome_windvel_6495_1081'],
                
                df_arome['/arome_airtemp_6495_1096'],
                df_arome['/arome_airpress_6495_1096'], 
                df_arome['/arome_winddir_6495_1096'],
                df_arome['/arome_windvel_6495_1096'],
            
                df_arome['/arome_airtemp_6491_1087'],
                df_arome['/arome_airpress_6491_1087'], 
                df_arome['/arome_winddir_6491_1087'],
                df_arome['/arome_windvel_6491_1087'],
                
                df_arome['/arome_airtemp_6486_1082'],
                df_arome['/arome_airpress_6486_1082'], 
                df_arome['/arome_winddir_6486_1082'],
                df_arome['/arome_windvel_6486_1082'],
                
                df_arome['/arome_airtemp_6486_1093'],
                df_arome['/arome_airpress_6486_1093'], 
                df_arome['/arome_winddir_6486_1093'],
                df_arome['/arome_windvel_6486_1093'],
    
                               
                df_tek['YVIK-YtreVikna1-Sum-produksjon']
    
               ],
    
               axis = 1)

# %%
data_2_0.to_csv('Data 2.0.csv', sep=';', index = False)

# %% [markdown]
# #### 'Data 2.1.csv'

# %%
data_2_1 = pd.concat([
                
                df_arome['/arome_airtemp_6495_1081'],
                df_arome['/arome_airpress_6495_1081'], 
                df_arome['/arome_winddir_6495_1081'],
                df_arome['/arome_windvel_6495_1081'],
                
                df_arome['/arome_airtemp_6495_1096'],
                df_arome['/arome_airpress_6495_1096'], 
                df_arome['/arome_winddir_6495_1096'],
                df_arome['/arome_windvel_6495_1096'],
            
                df_arome['/arome_airtemp_6491_1087'],
                df_arome['/arome_airpress_6491_1087'], 
                df_arome['/arome_winddir_6491_1087'],
                df_arome['/arome_windvel_6491_1087'],
                
                df_arome['/arome_airtemp_6486_1082'],
                df_arome['/arome_airpress_6486_1082'], 
                df_arome['/arome_winddir_6486_1082'],
                df_arome['/arome_windvel_6486_1082'],
                
                df_arome['/arome_airtemp_6486_1093'],
                df_arome['/arome_airpress_6486_1093'], 
                df_arome['/arome_winddir_6486_1093'],
                df_arome['/arome_windvel_6486_1093'],
    
                df_tek_delayed['YVIK-YtreVikna1-Sum-produksjon (2 hours before)'],
                               
                df_tek['YVIK-YtreVikna1-Sum-produksjon']
    
               ],
    
               axis = 1)

# %%
data_2_1.to_csv('Data 2.1.csv', sep=';', index = False)

# %% [markdown]
# #### 'Data 2.2.csv'

# %%
data_2_2 = pd.concat([
                
                df_arome['/arome_airtemp_6495_1081'],
                df_arome['/arome_airpress_6495_1081'], 
                df_arome['/arome_winddir_6495_1081'],
                df_arome['/arome_windvel_6495_1081'],
                
                df_arome['/arome_airtemp_6495_1096'],
                df_arome['/arome_airpress_6495_1096'], 
                df_arome['/arome_winddir_6495_1096'],
                df_arome['/arome_windvel_6495_1096'],
            
                df_arome['/arome_airtemp_6491_1087'],
                df_arome['/arome_airpress_6491_1087'], 
                df_arome['/arome_winddir_6491_1087'],
                df_arome['/arome_windvel_6491_1087'],
                
                df_arome['/arome_airtemp_6486_1082'],
                df_arome['/arome_airpress_6486_1082'], 
                df_arome['/arome_winddir_6486_1082'],
                df_arome['/arome_windvel_6486_1082'],
                
                df_arome['/arome_airtemp_6486_1093'],
                df_arome['/arome_airpress_6486_1093'], 
                df_arome['/arome_winddir_6486_1093'],
                df_arome['/arome_windvel_6486_1093'],
    
                df_antall_fungerende_vinturbiner['antall_fungerende'],
    
                df_tek_delayed['YVIK-YtreVikna1-Sum-produksjon (2 hours before)'],
                               
                df_tek['YVIK-YtreVikna1-Sum-produksjon']
    
               ],
    
               axis = 1)

# %%
data_2_2.to_csv('Data 2.2.csv', sep=';', index = False)

# %% [markdown]
# #### 'Data 2.3.csv'

# %%
data_2_3 = pd.concat([
                
                df_arome['/arome_airtemp_6495_1081'],
                df_arome['/arome_airpress_6495_1081'], 
                df_arome['/arome_winddir_6495_1081'],
                df_arome['/arome_windvel_6495_1081'],
                
                df_arome['/arome_airtemp_6495_1096'],
                df_arome['/arome_airpress_6495_1096'], 
                df_arome['/arome_winddir_6495_1096'],
                df_arome['/arome_windvel_6495_1096'],
            
                df_arome['/arome_airtemp_6491_1087'],
                df_arome['/arome_airpress_6491_1087'], 
                df_arome['/arome_winddir_6491_1087'],
                df_arome['/arome_windvel_6491_1087'],
                
                df_arome['/arome_airtemp_6486_1082'],
                df_arome['/arome_airpress_6486_1082'], 
                df_arome['/arome_winddir_6486_1082'],
                df_arome['/arome_windvel_6486_1082'],
                
                df_arome['/arome_airtemp_6486_1093'],
                df_arome['/arome_airpress_6486_1093'], 
                df_arome['/arome_winddir_6486_1093'],
                df_arome['/arome_windvel_6486_1093'],
    
                df_tek['STORM-YVik1-Vindhast-25km'],
                df_tek['STORM-YVik1-Vindretn-25km'],
    
                df_antall_fungerende_vinturbiner['antall_fungerende'],
    
                df_tek_delayed['YVIK-YtreVikna1-Sum-produksjon (2 hours before)'],
                               
                df_tek['YVIK-YtreVikna1-Sum-produksjon']
    
               ],
    
               axis = 1)

# %%
data_2_3.to_csv('Data 2.3.csv', sep=';', index = False)

# %% [markdown]
# ### Oversikt over vindturbiner

# %%
individuals = pd.concat([
                #df_tek['YVIK-YtreVikna1.-G1-T4015A3 -0104'],
                #df_tek['YVIK-YtreVikna1.-G2-T4015A3 -0104'],
                #df_tek['YVIK-YtreVikna1.-G3-T4015A3 -0104'],
                #df_tek['YVIK-YtreVikna1.-G4-T4015A3 -0104'],
                #df_tek['YVIK-YtreVikna1.-G5-T4015A3 -0104'],
                #df_tek['YVIK-YtreVikna1.-G6-T4015A3 -0104'],
                #df_tek['YVIK-YtreVikna1.-G7-T4015A3 -0104'],
                #df_tek['YVIK-YtreVikna1.-G8-T4015A3 -0104'],
                #df_tek['YVIK-YtreVikna1.-G9-T4015A3 -0104'],
                df_tek['YVIK-YtreVikna1-G10-T4015A3 -0104'],
                df_tek['YVIK-YtreVikna1-G11-T4015A3 -0104'],
                #df_tek['YVIK-YtreVikna1-G12-T4015A3 -0104'],
                #df_tek['YVIK-YtreVikna1-G13-T4015A3 -0104'],
                #df_tek['YVIK-YtreVikna1-G14-T4015A3 -0104'],
                #df_tek['YVIK-YtreVikna1-G15-T4015A3 -0104'],
                #df_tek['YVIK-YtreVikna1-G16-T4015A3 -0104'],
                #df_tek['YVIK-YtreVikna1-G17-T4015A3 -0104'],
                 
               ], 
               axis = 1)

# %%
individuals.head(250).plot(figsize=(20,8))

# %% [markdown]
# #### Se på enkeltmøller

# %%
df_tek['YVIK-YtreVikna1-G10-T4015A3 -0104 delayed'] = df_tek_delayed['YVIK-YtreVikna1-G10-T4015A3 -0104']

# %%
singel_10_2_3 = pd.concat([
                
                df_arome['/arome_airtemp_6495_1081'],
                df_arome['/arome_airpress_6495_1081'], 
                df_arome['/arome_winddir_6495_1081'],
                df_arome['/arome_windvel_6495_1081'],
                
                df_arome['/arome_airtemp_6495_1096'],
                df_arome['/arome_airpress_6495_1096'], 
                df_arome['/arome_winddir_6495_1096'],
                df_arome['/arome_windvel_6495_1096'],
            
                df_arome['/arome_airtemp_6491_1087'],
                df_arome['/arome_airpress_6491_1087'], 
                df_arome['/arome_winddir_6491_1087'],
                df_arome['/arome_windvel_6491_1087'],
                
                df_arome['/arome_airtemp_6486_1082'],
                df_arome['/arome_airpress_6486_1082'], 
                df_arome['/arome_winddir_6486_1082'],
                df_arome['/arome_windvel_6486_1082'],
                
                df_arome['/arome_airtemp_6486_1093'],
                df_arome['/arome_airpress_6486_1093'], 
                df_arome['/arome_winddir_6486_1093'],
                df_arome['/arome_windvel_6486_1093'],
    
                df_tek['STORM-YVik1-Vindhast-25km'],
                df_tek['STORM-YVik1-Vindretn-25km'],
    
                df_tek['YVIK-YtreVikna1-G10-T4015A3 -0104 delayed'],
                               
                df_tek['YVIK-YtreVikna1-G10-T4015A3 -0104']
    
               ],
    
               axis = 1)

# %%
singel_10_2_3.to_csv('Singel test.csv', sep=';', index = False)

# %%
# set time limit
time = 500

ax = df_tek['STORM-YVik1-Vindhast-25km'].head(time).plot(figsize=(20,8))
ax = df_tek['YVIK-YtreVikna1..-V1-T0016A3 -0108'].head(time).plot(figsize=(20,8))
ax = df_tek['YVIK-YtreVikna1..-V2-T0016A3 -0108'].head(time).plot(figsize=(20,8))
#ax = September['2 hours delay'].head(time).plot(figsize=(20,8))

 

plt.xlabel('Tid (timer)')
plt.ylabel('Vidhastighet')
plt.title('Utforskning av vindhastighet')

plt.legend(loc='best')

#remove spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Saves figure
fig = ax.get_figure()
#fig.savefig('24_punkter.png')

# %%
# set time limit
time = 1000

ax = df_tek['STORM-YVik1-Vindretn-25km'].head(time).plot(figsize=(20,8))
ax = df_tek['YVIK-YtreVikna1NP-V1-T0014A3.-0113'].head(time).plot(figsize=(20,8))
ax = df_tek['YVIK-YtreVikna1NP-V2-T0014A3.-0113'].head(time).plot(figsize=(20,8))
ax = df_tek['YVIK-YtreVikna1NP-V3-T0014A3.-0113'].head(time).plot(figsize=(20,8))
#ax = df_tek['YVIK-YtreVikna1NP-V4-T0014A3.-0113'].head(time).plot(figsize=(20,8))
ax = df_tek['YVIK-YtreVikna1NP-V5-T0014A3.-0113'].head(time).plot(figsize=(20,8))
ax = df_tek['YVIK-YtreVikna1NP-V6-T0014A3.-0113'].head(time).plot(figsize=(20,8))
ax = df_tek['YVIK-YtreVikna1NP-V7-T0014A3.-0113'].head(time).plot(figsize=(20,8))
ax = df_tek['YVIK-YtreVikna1NP-V8-T0014A3.-0113'].head(time).plot(figsize=(20,8))
ax = df_tek['YVIK-YtreVikna1NP-V9-T0014A3.-0113'].head(time).plot(figsize=(20,8))
ax = df_tek['YVIK-YtreVikna1NP-V10-T0014A3.-0113'].head(time).plot(figsize=(20,8))
#ax = September['2 hours delay'].head(time).plot(figsize=(20,8))

 

plt.xlabel('Tid (timer)')
plt.ylabel('Vidhastighet')
plt.title('Utforskning av vindhastighet')

plt.legend(loc='best')

#remove spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Saves figure
fig = ax.get_figure()
#fig.savefig('24_punkter.png')

# %%
# set time limit
time = 500

#ax = df_tek['YVIK-YtreVikna1-Sum-produksjon'].head(time).plot(figsize=(20,8))
ax = df_tek['STORM-YVik1-Vindhast-25km'].head(time).plot(figsize=(20,8))

ax = df_arome['/arome_windvel_6495_1081'].head(time).plot(figsize=(20,8))
ax = df_arome['/arome_windvel_6495_1096'].head(time).plot(figsize=(20,8))
ax = df_arome['/arome_windvel_6491_1087'].head(time).plot(figsize=(20,8))
ax = df_arome['/arome_windvel_6486_1082'].head(time).plot(figsize=(20,8))
ax = df_arome['/arome_windvel_6486_1093'].head(time).plot(figsize=(20,8))




plt.xlabel('Tid (timer)')
plt.ylabel('Vidhastighet')
plt.title('Utforskning av vindhastighet')

plt.legend(loc='best')

#remove spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Saves figure
fig = ax.get_figure()
#fig.savefig('24_punkter.png')

# %%
df_tek['gjennomsnitt'] = (df_tek['STORM-YVik1-Vindhast-25km'] + df_arome['/arome_windvel_6491_1087'] )/2

# %%
# set time limit
time = 200

#ax = df_tek['YVIK-YtreVikna1-Sum-produksjon'].head(time).plot(figsize=(20,8))

#ax = df_tek['YVIK-YtreVikna1-Sum-produksjon'].head(time).plot(figsize=(20,8))
ax = df_tek['STORM-YVik1-Vindhast-25km'].head(time).plot(figsize=(20,8))

ax = df_tek['DNMI_75220...........T0015A3-0120'].head(time).plot(figsize=(20,8))

ax = df_arome['/arome_windvel_6495_1081'].head(time).plot(figsize=(20,8))
ax = df_arome['/arome_windvel_6495_1096'].head(time).plot(figsize=(20,8))
ax = df_arome['/arome_windvel_6491_1087'].head(time).plot(figsize=(20,8))
ax = df_arome['/arome_windvel_6486_1082'].head(time).plot(figsize=(20,8))
ax = df_arome['/arome_windvel_6486_1093'].head(time).plot(figsize=(20,8))

#ax = df_tek['gjennomsnitt'].head(time).plot(figsize=(20,8))


plt.xlabel('Tid (timer)')
plt.ylabel('Vidhastighet')
plt.title('Utforskning av vindhastighet')

plt.legend(loc='best')

#remove spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Saves figure
fig = ax.get_figure()
#fig.savefig('24_punkter.png')
