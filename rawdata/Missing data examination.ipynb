# %%
import pandas as pd
import numpy as np

#For PCA
from sklearn.decomposition import PCA

# Visualization
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# Making plots look better
import matplotlib as mpl
mpl.rcParams['patch.force_edgecolor'] = True

# %config InlineBackend.figure_format = 'retina'

# %%
df = pd.read_csv('vindkraft 130717-160218 arome.csv', sep=';', low_memory = False)
df.head(5)
# Out:
#          Unnamed: 0 /arome_airpress_6276_0782 /arome_airpress_6280_0870  \
# 0        13.07.2017                  991,2569                  956,1969
# 1  13.07.2017 01:00                  991,5031                  956,3381
# 2  13.07.2017 02:00                  991,6381                  956,5481
# 3  13.07.2017 03:00                  991,8706                  956,9956
# 4  13.07.2017 04:00                 991,84375                 957,09375
#
#   /arome_airpress_6283_0958 /arome_airpress_6287_1051  \
# 0                  917,1469                  930,2269
# 1                  917,1481                  930,5681
# 2                  917,3931                  930,6981
# 3                  917,9256                  930,9956
# 4                 918,27375                 931,50875
#
#   /arome_airpress_6322_0961 /arome_airpress_6323_0780  \
# 0                  984,9569                 1013,3369
# 1                  985,1181                 1013,6631
# 2                  985,4231                 1013,8931
# 3                  985,8606                 1014,3006
# 4                 985,99375                1014,33875
#
#   /arome_airpress_6323_0870 /arome_airpress_6323_1051  \
# 0                  944,3019                  974,9519
# 1                  944,3931                  975,0731
# 2                  944,6431                  975,3281
# 3                  945,0856                  975,7906
# 4                 945,30375                 976,20375
#
#   /arome_airpress_6323_1141           ...            /arome_windvel_6562_0873  \
# 0                  930,2119           ...                          7,55708746
# 1                  930,3631           ...                         7,746818335
# 2                  930,6831           ...                         7,512738058
# 3                  931,2456           ...                         9,131114778
# 4                 931,63375           ...                         9,501708411
#
#   /arome_windvel_6565_0960 /arome_windvel_6565_1179 /arome_windvel_6565_1190  \
# 0              9,450577555              7,531090041              7,799992662
# 1              8,962845585              7,229139068              7,475844206
# 2              8,583397826              6,999961946              7,880006156
# 3              8,419821316              7,181705283              7,764034095
# 4              8,279912026              6,833332755              7,120517022
#
#   /arome_windvel_6568_1053 /arome_windvel_6569_1184 /arome_windvel_6571_1140  \
# 0              11,00409383              9,831423231              11,94151005
# 1              10,70240138              9,257466914              10,97799893
# 2              9,848485785              8,776299074              10,85063634
# 3               9,59448935              9,036273734              10,60879442
# 4               8,61591041              8,665531622              10,26011536
#
#   /arome_windvel_6571_1178 /arome_windvel_6572_1194 /arome_windvel_6573_1232
# 0              11,90659021              12,00871854              8,986468034
# 1              11,18495255              11,44201567              8,769423021
# 2               10,6863432              11,03157442              8,613651526
# 3              11,08344377              11,39512173              8,096855067
# 4              11,07923125              10,47193263              7,685383196
#
# [5 rows x 489 columns]

# %%
df.describe()
# Out:
#               Unnamed: 0 /arome_airpress_6276_0782 /arome_airpress_6280_0870  \
# count               5239                      5192                      5192
# unique              5239                      4988                      5014
# top     24.11.2017 10:00                  991,5031                  982,5994
# freq                   1                         3                         3
#
#        /arome_airpress_6283_0958 /arome_airpress_6287_1051  \
# count                       5192                      5192
# unique                      5029                      5016
# top                        982,8                  908,1994
# freq                           3                         3
#
#        /arome_airpress_6322_0961 /arome_airpress_6323_0780  \
# count                       5192                      5192
# unique                      5003                      4975
# top                    993,64125                1013,38375
# freq                           3                         3
#
#        /arome_airpress_6323_0870 /arome_airpress_6323_1051  \
# count                       5192                      5192
# unique                      5039                      4979
# top                    1001,3519                 977,01125
# freq                           3                         3
#
#        /arome_airpress_6323_1141           ...             \
# count                       5192           ...
# unique                      4986           ...
# top                     938,7306           ...
# freq                           3           ...
#
#        /arome_windvel_6562_0873 /arome_windvel_6565_0960  \
# count                      5192                     5192
# unique                     5185                     5185
# top                 7,512738058              8,525525774
# freq                          2                        2
#
#        /arome_windvel_6565_1179 /arome_windvel_6565_1190  \
# count                      5192                     5192
# unique                     5185                     5185
# top                 7,531090041              7,764034095
# freq                          2                        2
#
#        /arome_windvel_6568_1053 /arome_windvel_6569_1184  \
# count                      5192                     5192
# unique                     5185                     5185
# top                  9,59448935              9,257466914
# freq                          2                        2
#
#        /arome_windvel_6571_1140 /arome_windvel_6571_1178  \
# count                      5192                     5192
# unique                     5185                     5185
# top                 10,26011536              11,90659021
# freq                          2                        2
#
#        /arome_windvel_6572_1194 /arome_windvel_6573_1232
# count                      5192                     5192
# unique                     5185                     5185
# top                 12,00871854              7,685383196
# freq                          2                        2
#
# [4 rows x 489 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5239 entries, 0 to 5238
# Columns: 489 entries, Unnamed: 0 to /arome_windvel_6573_1232
# dtypes: object(489)
# memory usage: 19.5+ MB

# %%
pca = PCA(n_components = 10)
pca.fit(df)
pca.components_
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-13cbb56e5238> in <module>()
#       1 pca = PCA(n_components = 10)
# ----> 2 pca.fit(df)
#       3 pca.components_
#
# C:\Users\fabia\Anaconda3\lib\site-packages\sklearn\decomposition\pca.py in fit(self, X, y)
#     305             Returns the instance itself.
#     306         """
# --> 307         self._fit(X)
#     308         return self
#     309
#
# C:\Users\fabia\Anaconda3\lib\site-packages\sklearn\decomposition\pca.py in _fit(self, X)
#     344
#     345         X = check_array(X, dtype=[np.float64], ensure_2d=True,
# --> 346                         copy=self.copy)
#     347
#     348         # Handle n_components==None
#
# C:\Users\fabia\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     380                                       force_all_finite)
#     381     else:
# --> 382         array = np.array(array, dtype=dtype, order=order, copy=copy)
#     383
#     384         if ensure_2d:
#
# ValueError: could not convert string to float: '12,16587427'
